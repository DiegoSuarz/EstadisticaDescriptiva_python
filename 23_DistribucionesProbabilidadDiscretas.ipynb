# %%
from scipy.stats import bernoulli
import matplotlib.pyplot as plt

# %%
p = 0.7 
mean, var, skew, kurt = bernoulli.stats(p, moments = 'mvsk')
print("Media %f"%mean)
print("Varianza %f"%var)
print("Sesgo %f "%skew)
print("Curtosis %f"%kurt)
# Out:
# Media 0.700000
# Varianza 0.210000
# Sesgo -0.872872
# Curtosis -1.238095

# %%
# Funcion de probabilidad:
fix, ax = plt.subplots(1,1)
x = bernoulli.rvs(p, size = 1000)
ax.plot(x)
plt.show()

# %% [markdown]
# ## Distribucion Binomial

# %%
from scipy.stats import binom
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(1,1)
n = 7
p = 0.4

mean, var,  skew, kurt = binom.stats(n, p, moments = "mvsk")

x = np.arange(0, n+1)
ax.plot(x, binom.pmf(x, n, p), 'bo', ms = 8, label = "Funcion de densidad de B(7,0.4)")
ax.vlines(x, 0, binom.pmf(x, n, p), colors = 'b', lw = 4, alpha = 0.5)
rv = binom(n ,p)
ax.vlines(x, 0, rv.pmf(x), colors = 'k', linestyles='--', lw=1,
          label="Distribucion teorica")

ax.legend( loc = 'best', frameon = False)
plt.show()

# %%
print("Media %f"%mean)
print("Varianza %f"%var)
print("Sesgo %f "%skew)
print("Curtosis %f"%kurt)
# Out:
# Media 2.800000
# Varianza 1.680000
# Sesgo 0.154303
# Curtosis -0.261905

# %%
ax.plot(x, binom.cdf(x, n, p), 'bo', ms = 8, label = "Funcion de densidad de B(7,0.4)")
ax.vlines(x, 0, binom.cdf(x, n, p), colors = 'b', lw = 4, alpha = 0.5)
rv = binom(n ,p)
ax.vlines(x, 0, rv.pmf(x), colors = 'k', linestyles='--', lw=1,
          label="Distribucion teorica")

ax.legend( loc = 'best', frameon = False)
plt.show()

# %%
r = binom.rvs(n, p , size = 10)
r
# Out:
# array([6, 4, 3, 4, 4, 1, 2, 0, 2, 3])

# %%
fix, ax = plt.subplots(1,1)
r = binom.rvs(n, p , size = 10)
ax.hist(r, bins = n)
plt.show()

# %% [markdown]
# ## Distribución Geométrica:

# %%
from scipy.stats import geom
import matplotlib.pyplot as plt
import numpy as np

p = 0.3

mean, var, skew, kurt =geom.stats(p, moments = 'mvsk')

print("Media %f"%mean)
print("Varianza %f"%var)
print("Sesgo %f "%skew)
print("Curtosis %f"%kurt)
# Out:
# Media 3.333333
# Varianza 7.777778
# Sesgo 2.031889
# Curtosis 6.128571

# %%
x = np.arange(geom.ppf(0.01, p), geom.ppf(0.99, p))
prob = geom.ppf(x, p)

fig, ax = plt.subplots(1,1)
ax.plot(x ,prob , 'bo', ms= 8, label = 'Función de probabilidad de Geom(0.3)')
ax.vlines(x, 0, geom.ppf(x, p), colors = 'b', lw = 4, alpha = 0.5)


rv = geom(p)
ax.vlines(x, 0 , rv.pmf(x), colors= 'k', linestyles= '--', lw = 1, label = "Frozen PMF")
ax.legend(loc = 'best')
plt.show()

# %%
fig, ax = plt.subplots(1,1)
prob = geom.cdf(x, p)
ax.plot(x, prob, 'bo', ms = 8, label = "Funcion de distribucion acumulada")
plt.show()

# %%
fig, ax = plt.subplots(1,1)
r = geom.rvs(p, size = 10000)
plt.hist(r)
plt.show()

# %% [markdown]
# ## Distribucion Hipergeométrica:

# %% [markdown]
# ### Ejemplo:
#
# Supongamos que tenemos 20 animales, de los cuales 7 son perros. (el resto son no perros). Queremos medir la probabilidad de encontrar un número determinado de perros si elegimos $x = 12$ animales al azar.

# %%
from scipy.stats import hypergeom
import matplotlib.pyplot as plt
import numpy as np

mean, var, skew, kurt = rv.stats(moments = 'mvsk')

print("Media %f"%mean)
print("Varianza %f"%var)
print("Sesgo %f "%skew)
print("Curtosis %f"%kurt)
# Out:
# Media 4.200000
# Varianza 1.149474
# Sesgo -0.062181
# Curtosis -0.152661

# %%
[M, n, N] = [20, 7, 12]
rv = hypergeom(M, n, N)
x = np.arange(0, n+1)
y = rv.pmf(x)

fig = plt.figure()
ax = fig.add_subplot(111)
ax.vlines(x, 0, y, lw = 2, alpha = 0.5)
ax.set_xlabel("Número de perros entre los 12 elegidos al azar")
ax.set_ylabel("Distribución de probabilidad de H(13,7,12)")
plt.show()

# %% [markdown]
# ## Distribucion de Poisson
#
# Ejemplo:
# Supongamos que $X$ modela el número  de errores por pagina que tiene un vllor esperado $\lambda = 5$

# %%
import numpy as np
from scipy.stats import poisson
import matplotlib.pyplot as plt

mu = 5
x = np.arange(0, 12)

mean, var, skew, kurt = poisson.stats(mu, moments = 'mvsk')

print("Media %f"%mean)
print("Varianza %f"%var)
print("Sesgo %f "%skew)
print("Curtosis %f"%kurt)
# Out:
# Media 5.000000
# Varianza 5.000000
# Sesgo 0.447214
# Curtosis 0.200000

# %%
fig, ax = plt.subplots(1,1)
ax.plot(x, poisson.pmf(x, mu), 'bo', ms = 8, label = 'Poisson(0.8)')
ax.vlines(x, 0, poisson.pmf(x, mu), colors= 'b', lw = 4, alpha = 0.5)
ax.legend(loc = 'best', frameon = False)
plt.show()
